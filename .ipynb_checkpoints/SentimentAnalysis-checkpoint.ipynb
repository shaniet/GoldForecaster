# %%
import pandas as pd
import glob
from ast import literal_eval
import matplotlib.pyplot as plt
plt.style.use('dark_background')
pd.options.display.max_colwidth = 100
import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ### Concat all files together

# %%
all_files = glob.glob("data/*.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))
df['date'] = pd.to_datetime(df['date']) # sets format of "date" column as datetime
df = df[df['headline'].notna()].drop_duplicates().sort_values(by='date') 
df['keywords'] = df['keywords'].apply(literal_eval)
df
# Out:
#                                                                   headline  \
# 3                                   For Sand Detective, Beaches Yield Gold
# 2                                                              Commodities
# 8                          DOLLAR CONTINUES TO FALL ON SOME MARKETS ABROAD
# 0                                    ‘GOLD RUSH’ SET OFF BY DOLLAR'S SLUMP
# 6                                      DOLLAR PLAN ROCKS FUTURES IN METALS
# ..                                                                     ...
# 0                                             Jewelry That Adds Face Value
# 2   Menendez Investigation Is Said to Involve Questions About Luxury Gifts
# 1                                             $900,000 Homes in California
# 5                 Mayor Adams Loves a Good Tale. Some of Them May Be Tall.
# 3            In Samuel Fosso’s Photos, ‘You Can See Evil, You Can See God’
#
#          date doc_type material_type  section  \
# 3  1978-01-01  article      Archives      NaN
# 2  1978-01-02  article      Archives      NaN
# 8  1978-01-03  article      Archives      NaN
# 0  1978-01-04  article      Archives      NaN
# 6  1978-01-05  article      Archives      NaN
# ..        ...      ...           ...      ...
# 0  2023-05-26  article          News      NaN
# 2  2023-05-26  article          News      NaN
# 1  2023-05-29  article          News      NaN
# 5  2023-06-01  article          News      NaN
# 3  2023-06-01  article          News      NaN
#
#                                                                           keywords
# 3                                                   [Metals and Minerals, Beaches]
# 2                                                                       [Currency]
# 8                                                                       [Currency]
# 0                                                                       [Currency]
# 6                                                                       [Currency]
# ..                                                                             ...
# 0   [Jewels and Jewelry, Body Piercing, Lips (Body Part), Nose, your-feed-fashion]
# 2                            [Halal Foods and Products, Gifts to Public Officials]
# 1                                          [Real Estate and Housing (Residential)]
# 5                                         [Mayors, Content Type: Personal Profile]
# 3                               [Art, Photography, Content Type: Personal Profile]
#
# [6194 rows x 6 columns]

# %% [markdown]
# ### Run sentiment analysis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# Instantiate the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Get the headline and keywords
    headline = row['headline']
    keywords = row['keywords']
    
    # Combine the headline and keywords into one string
    text = headline + ' ' + ' '.join(keywords)
    # Check if "s&p 500" is in the text
    if "gold" not in text.lower():
        continue

    
    # Get the sentiment score for the text
    sentiment = sia.polarity_scores(text)['compound']
    # Add the sentiment score to the DataFrame
    df.at[index, 'sentiment'] = sentiment
# Add a new column to the DataFrame for the date of the article
df['article_date'] = pd.to_datetime(df['date']).dt.date

# Group the DataFrame by article date and aggregate the sentiment scores
sentiment_by_day = df.groupby('article_date')['sentiment'].mean()

df['week'] = pd.to_datetime(df['date']).dt.to_period('W')
sentiment_by_week = df.groupby('week')['sentiment'].mean()


df['month'] = pd.to_datetime(df['date']).dt.to_period('M')
sentiment_by_month = df.groupby('month')['sentiment'].mean()


sentiment_by_week.to_csv('news.csv', header=True)

# %% [markdown]
# ### Sentiment by Day

# %%
import matplotlib.pyplot as plt

plt.plot(sentiment_by_day.index, sentiment_by_day.values)
plt.xlabel('Date')
plt.ylabel('Sentiment Index')
plt.title('Sentiment over Time (by day ')
plt.show()

# %% [markdown]
# ### Sentiment by Week

# %%
# plot sentiment by week with time as the x value
plt.plot(sentiment_by_week.index.to_timestamp(), sentiment_by_week.values)
plt.xlabel('Time')
plt.ylabel('Sentiment')
plt.title('Sentiment by Week')
plt.show()

# %%
# plot sentiment by month with time as the x value
plt.plot(sentiment_by_month.index.to_timestamp(), sentiment_by_month.values)
plt.xlabel('Time')
plt.ylabel('Sentiment')
plt.title('Sentiment by Month')
plt.show()
# Out:
# month
# 1978-01    0.241548
# 1978-02    0.282663
# 1978-03    0.243830
# 1978-04    0.276590
# 1978-05    0.257369
#              ...
# 2023-02    0.248790
# 2023-03    0.248790
# 2023-04    0.248790
# 2023-05    0.157612
# 2023-06    0.613500
# Freq: M, Name: sentiment, Length: 544, dtype: float64

# %%
sentiment_by_month.to_csv('sentiment.csv', index=True)
